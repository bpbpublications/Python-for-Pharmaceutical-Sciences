# %% [markdown]
# # Chapter 1: Python and Pharmaceutical Sciences
#
# **B.Pharm companion Jupyter notebook — worked examples and concept demonstrations**
#
# ## Chapter focus
#
# Set up a Python learning environment, understand notebook cells and the kernel, and run the first medicine and batch-record examples.
#
# ## Pharmacy context
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.
#
# ## Important notes and how to use this notebook
#
# 1. Use a Python 3 kernel. Read the problem and algorithm, predict the result, then run the cell with **Shift+Enter**.
# 2. Choose **Restart Kernel and Run All Cells** to reproduce the saved outputs. Run from top to bottom; later demonstrations may use earlier variables.
# 3. Outputs below code cells were produced by execution. Paths, versions, memory diagnostics and set display order can differ between computers.
# 4. All records are simulated for education. Retain units and distinguish a descriptive result from a clinical or regulatory decision.
# 5. Files written by examples are kept in `outputs/chapter_01`. Rerunning a file-writing example replaces its own generated output.
#
# These examples use the Python standard library; no external dataset is needed.

# %%
from pathlib import Path

WORKSHOP_ROOT = Path.cwd().resolve()
OUTPUT_DIR = WORKSHOP_ROOT / "outputs" / "chapter_01"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("Chapter 1 ready. Generated files: outputs/chapter_01")
# Out:
# Chapter 1 ready. Generated files: outputs/chapter_01

# %% [markdown]
# ## Contents
#
# - [01. 1.6.6 Creating and running the first notebook](#example-1-1)
# - [02. 1.8.1 Installation steps](#example-1-2)
# - [03. 1.12.1 Importance of restarting and running all cells](#example-1-3)
# - [04. 1.14.2 Part B: Executing the cells](#example-1-4)
# - [05. 1.14.2 Part B: Executing the cells](#example-1-5)

# %% [markdown]
# <a id="example-1-1"></a>
#
# ## 01. 1.6.6 Creating and running the first notebook
#
# ### Problem statement
#
# Demonstrate creating and running the first notebook using the simulated values or objects in the cell below.
#
# ### Objective
#
# Understand how the Python operations in this example support creating and running the first notebook and interpret the result correctly.
#
# ### Pharmacy context
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.
#
# ### Algorithm
#
# 1. Store `'Paracetamol'` in `medicine_name`.
# 2. Store `500` in `tablet_strength_mg`.
# 3. Display the results for inspection.
#
# ### Code and executed output
#
# The output appears directly below the code cell.

# %%
medicine_name = "Paracetamol"
tablet_strength_mg = 500
print("Medicine:", medicine_name)
print("Strength:", tablet_strength_mg, "mg")
# Out:
# Medicine: Paracetamol
# Strength: 500 mg

# %% [markdown]
# ### Explanation
#
# Expected output: Medicine: Paracetamol and Strength: 500 mg. The value 500 is only a programming example; it is not a prescribing or dosing instruction.
#
# ### Interpretation
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.

# %% [markdown]
# <a id="example-1-2"></a>
#
# ## 02. 1.8.1 Installation steps
#
# ### Problem statement
#
# Demonstrate installation steps using the simulated values or objects in the cell below.
#
# ### Objective
#
# Understand how the Python operations in this example support installation steps and interpret the result correctly.
#
# ### Pharmacy context
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.
#
# ### Algorithm
#
# 1. Store `'BPH-001'` in `batch_number`.
# 2. Store `120` in `stock_units`.
# 3. Display the results for inspection.
#
# ### Code and executed output
#
# The output appears directly below the code cell.

# %%
batch_number = "BPH-001"
stock_units = 120
print("Batch:", batch_number)
print("Stock units:", stock_units)
# Out:
# Batch: BPH-001
# Stock units: 120

# %% [markdown]
# ### Explanation
#
# Enter the program and select the green Run button, or use the Windows shortcut Shift+F10 for the current run configuration.
#
# ### Interpretation
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.

# %% [markdown]
# <a id="example-1-3"></a>
#
# ## 03. 1.12.1 Importance of restarting and running all cells
#
# ### Problem statement
#
# Demonstrate importance of restarting and running all cells using the simulated values or objects in the cell below.
#
# ### Objective
#
# Understand how the Python operations in this example support importance of restarting and running all cells and interpret the result correctly.
#
# ### Pharmacy context
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.
#
# ### Algorithm
#
# 1. Store `500` in `tablet_weight_mg`.
# 2. Display the results for inspection.
#
# ### Code and executed output
#
# The output appears directly below the code cell.

# %%
# Cell 1
tablet_weight_mg = 500

# Cell 2
print(tablet_weight_mg)
# Out:
# 500

# %% [markdown]
# ### Explanation
#
# Jupyter remembers variables created earlier in the current kernel. A notebook may appear to work even when cells were executed in a confusing order. Before submission, save the notebook, restart the kernel, and run all cells from top to bottom. If it still works, the notebook is more reproducible.
#
# ### Interpretation
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.

# %% [markdown]
# <a id="example-1-4"></a>
#
# ## 04. 1.14.2 Part B: Executing the cells
#
# ### Problem statement
#
# Demonstrate part B: Executing the cells using the simulated values or objects in the cell below.
#
# ### Objective
#
# Understand how the Python operations in this example support part b: executing the cells and interpret the result correctly.
#
# ### Pharmacy context
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.
#
# ### Algorithm
#
# 1. Display the results for inspection.
#
# ### Code and executed output
#
# The output appears directly below the code cell.

# %%
print("Python is working correctly.")
# Out:
# Python is working correctly.

# %% [markdown]
# ### Explanation
#
# Read the statements in order. The saved result shows the values produced by this cell; compare the value and its type or unit with the algorithm.
#
# ### Interpretation
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.

# %% [markdown]
# <a id="example-1-5"></a>
#
# ## 05. 1.14.2 Part B: Executing the cells
#
# ### Problem statement
#
# Demonstrate part B: Executing the cells using the simulated values or objects in the cell below.
#
# ### Objective
#
# Understand how the Python operations in this example support part b: executing the cells and interpret the result correctly.
#
# ### Pharmacy context
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.
#
# ### Algorithm
#
# 1. Store `'Paracetamol'` in `medicine_name`.
# 2. Store `'BPH-001'` in `batch_number`.
# 3. Store `120` in `stock_units`.
# 4. Display the results for inspection.
#
# ### Code and executed output
#
# The output appears directly below the code cell.

# %%
medicine_name = "Paracetamol"
batch_number = "BPH-001"
stock_units = 120
print("Medicine:", medicine_name)
print("Batch:", batch_number)
print("Stock units:", stock_units)
# Out:
# Medicine: Paracetamol
# Batch: BPH-001
# Stock units: 120

# %% [markdown]
# ### Explanation
#
# Read the statements in order. The saved result shows the values produced by this cell; compare the value and its type or unit with the algorithm.
#
# ### Interpretation
#
# Medicine names, labelled strengths, batch codes and stock counts make the first Python instructions familiar. Displaying a value does not validate the underlying medicine record.

# %% [markdown]
# ## Review and practice
#
# - Change one simulated input and predict the effect before rerunning the relevant cell.
# - State the unit and meaning of each reported result.
# - Explain one input condition or limitation that matters for the example.
# - Restart the kernel and run all cells to check that the notebook is reproducible.
#
# ## Source and validation
#
# Adapted from **2992_01_Final_KS_Revised.docx**. Worked programs and the complete code demonstrations are retained in chapter order. Installation commands are optional instructions; intentionally broken debugging examples are shown as corrected solutions. Notebook-specific changes are recorded in `Notebook_Guide_and_Validation.md`.
